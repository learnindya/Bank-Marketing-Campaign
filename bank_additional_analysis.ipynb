# %%
## Pandas dan Numpy
import pandas as pd
import numpy as np

# Visualization Library
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as st
from scipy.stats import chi2_contingency

# %%
bank = pd.read_csv('bank-full.csv', engine='python', sep=None)
bank.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
# divide numerical & categorical data
numerical = bank.select_dtypes(exclude='object')
categorical = bank.select_dtypes(include='object')
num = numerical.columns
cat = categorical.columns

# %%
ax = sns.countplot(data=bank, x="job", hue="y", dodge=False, palette="RdYlBu")

plt.yscale('log')

# Calculate and display percentages on top of each bar
for p in ax.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x()
    y = p.get_y()
    percentage = f'{height / total :.1%}'
    ax.annotate(percentage, (x + width / 2, y + height * 1.05),ha='center', fontsize=9)

plt.title('Distribution of job')
plt.xticks(rotation=45)
plt.tight_layout()

# %%
ax = sns.countplot(data=bank, x="marital", hue="y", dodge=False, palette="RdBu")

plt.yscale('log')

# Calculate and display percentages on top of each bar
for p in ax.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x()
    y = p.get_y()
    percentage = f'{height / total :.1%}'
    ax.annotate(percentage, (x + width / 2, y + height * 1.05),ha='center', fontsize=9)

plt.title('Distribution of marital')
plt.tight_layout()

# %%
ax = sns.countplot(data=bank, x="education", hue="y", dodge=False, palette="PuOr")

plt.yscale('log')

# Calculate and display percentages on top of each bar
for p in ax.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x()
    y = p.get_y()
    percentage = f'{height / total :.1%}'
    ax.annotate(percentage, (x + width / 2, y + height * 1.05),ha='center', fontsize=9)

plt.title('Distribution of education')
plt.tight_layout()

# %%
ax = sns.countplot(data=bank, x="default", hue="y", dodge=False, palette="Spectral")

plt.yscale('log')

# Calculate and display percentages on top of each bar
for p in ax.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x()
    y = p.get_y()
    percentage = f'{height / total :.1%}'
    ax.annotate(percentage, (x + width / 2, y + height * 1.05),ha='center', fontsize=9)

plt.title('Distribution of default')
plt.tight_layout()

# %%
ax = sns.countplot(data=bank, x="housing", hue="y", dodge=False, palette="bwr")

plt.yscale('log')

# Calculate and display percentages on top of each bar
for p in ax.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x()
    y = p.get_y()
    percentage = f'{height / total :.1%}'
    ax.annotate(percentage, (x + width / 2, y + height * 1.01),ha='center', fontsize=9)

plt.title('Distribution of housing')
plt.tight_layout()

# %%
ax = sns.countplot(data=bank, x="loan", hue="y", dodge=False, palette="tab20c_r")

plt.yscale('log')

# Calculate and display percentages on top of each bar
for p in ax.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x()
    y = p.get_y()
    percentage = f'{height / total :.1%}'
    ax.annotate(percentage, (x + width / 2, y + height * 1.01),ha='center', fontsize=9)

plt.title('Distribution of loan')
plt.tight_layout()

# %%
ax = sns.countplot(data=bank, x="contact", hue="y", dodge=False, palette="pastel")

plt.yscale('log')

# Calculate and display percentages on top of each bar
for p in ax.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x()
    y = p.get_y()
    percentage = f'{height / total :.1%}'
    ax.annotate(percentage, (x + width / 2, y + height * 1.05),ha='center', fontsize=9)

plt.title('Distribution of contact')
plt.tight_layout()

# %%
ax = sns.countplot(data=bank, x="month", hue="y", dodge=False, palette="pastel")

plt.yscale('log')

# Calculate and display percentages on top of each bar
for p in ax.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x()
    y = p.get_y()
    percentage = f'{height / total :.1%}'
    ax.annotate(percentage, (x + width / 2, y + height * 1.05),ha='center', fontsize=8)

plt.title('Distribution of month')
plt.tight_layout()

# %%
ax = sns.countplot(data=bank, x="poutcome", hue="y", dodge=False, palette="pastel")

plt.yscale('log')

# Calculate and display percentages on top of each bar
for p in ax.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x()
    y = p.get_y()
    percentage = f'{height / total :.1%}'
    ax.annotate(percentage, (x + width / 2, y + height),ha='center', fontsize=9)

plt.title('Distribution of education')
plt.tight_layout()

# %%
# Build a function to show categorical values disribution
def plot_bar(column):
    # temp df 
    temp_1 = pd.DataFrame()
    # count categorical values
    temp_1['No deposit'] = bank[bank['y'] == 'no'][column].value_counts()
    temp_1['Yes deposit'] = bank[bank['y'] == 'yes'][column].value_counts()
    temp_1.plot(kind='bar')
    plt.xlabel(f'{column}')
    plt.ylabel('Number of clients')
    plt.title('Distribution of {} and deposit'.format(column))
    plt.show();

plot_bar('job'), plot_bar('marital'), plot_bar('education'), plot_bar('default'), plot_bar('housing'), plot_bar('loan'), plot_bar('contact'), plot_bar('month'), plot_bar('poutcome')
# Out:
# (None, None, None, None, None, None, None, None, None)

# %%
for i, column in enumerate(cat, 1):
    plt.figure(figsize=(6, 50))
    plt.subplot(10, 1, i)
    
    # Create a contingency table
    table_bar = pd.crosstab(bank[column], bank['y'])
    
    # Plot the stacked bar chart
    ax = table_bar.plot(kind='bar', stacked=True, color=['skyblue', 'orange'], width=0.8, ax=plt.gca())

    plt.title(f'Distribution of {column}')
    plt.ylabel('Number of clients')

    # Calculate and display percentages on top of each bar
    total = len(bank[column])
    for p in plt.gca().patches:
        height = p.get_height()
        width = p.get_width()
        x, y = p.get_x(), p.get_y()
        plt.text(x + width / 2, y + height / 1.2, f'{height / total:.1%}', ha='center', va='center', fontsize=8)

    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.legend()

# %%
custom_palette = {'yes': 'orange', 'no': 'skyblue'}

# %%
for i in range(0, len(cat)):
    plt.figure(figsize=(6, 45))
    plt.subplot(10, 1, i+1)
    
    ax = sns.countplot(data=bank, x=cat[i], hue="y", dodge=False, palette="PuOr")

    plt.yscale('log')

    # Calculate and display percentages on top of each bar
    for p in ax.patches:
        height = p.get_height()
        width = p.get_width()
        x = p.get_x()
        y = p.get_y()
        percentage = f'{height / total :.1%}'
        ax.annotate(percentage, (x + width / 2, y + height * 1.02),ha='center', fontsize=8)

    plt.title(f'Distribution of {cat[i]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
# Feature importance based on Random Forest classifier

from sklearn.ensemble import RandomForestClassifier

df_feature = numericals.copy()

X = df_feature.drop(['TravelInsurance', 'Unnamed: 0'], axis=1)
y = df['TravelInsurance']

model = RandomForestClassifier()
model.fit(X, y)

feature_importance = pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=False)
feature_importance

# %%
# Feature importance based on Decision Tree classifier

from sklearn.tree import DecisionTreeClassifier

X = df_feature.drop(['TravelInsurance', 'Unnamed: 0'], axis=1)
y = df['TravelInsurance']

model = DecisionTreeClassifier()
model.fit(X, y)

feature_importance = pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=False)
feature_importance

# %%
# Feature importance based on XG Boost classifier

from xgboost import XGBClassifier

X = df_feature.drop(['TravelInsurance', 'Unnamed: 0'], axis=1)
y = df['TravelInsurance']

model = XGBClassifier()
model.fit(X, y)

feature_importance = pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=False)
feature_importance
